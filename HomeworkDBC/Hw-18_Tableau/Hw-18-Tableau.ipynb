# %%
import os
import csv
import datetime

import pandas as pd
import numpy as np

# %%
data = "Resources/CitiBikeRidership-MembershipData2017-2019.csv"
Mem_data = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Mem_data.head()

#verify column names for merge
#Mem_data2017_Q2.columns
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/2017                                              23849
# 1  4/2/2017                                              39779
# 2  4/3/2017                                              43484
# 3  4/4/2017                                              29990
# 4  4/5/2017                                              47635
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        67299
# 1                                       130087
# 2                                       104217
# 3                                        63091
# 4                                       108281
#
#    Total Annual Members (All Time)  \
# 0                           210739
# 1                           210915
# 2                           211075
# 3                           211171
# 4                           211310
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
data = "Resources/CitiBikeRidership-TripData2017-2019.csv"
Trip_data = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data = pd.DataFrame(Trip_data)
Trip_data.head()
# Out:
#    tripduration      starttime       stoptime  start station id  \
# 0           499  6/1/2017 0:01  6/1/2017 0:09              3195
# 1           507  6/1/2017 0:06  6/1/2017 0:15              3211
# 2           768  6/1/2017 0:44  6/1/2017 0:57              3195
# 3           101  6/1/2017 1:12  6/1/2017 1:14              3185
# 4           265  6/1/2017 1:14  6/1/2017 1:18              3273
#
#   start station name  start station latitude  start station longitude  \
# 0            Sip Ave               40.730743               -74.063784
# 1         Newark Ave               40.721525               -74.046305
# 2            Sip Ave               40.730743               -74.063784
# 3          City Hall               40.717733               -74.043845
# 4       Manila & 1st               40.721651               -74.042884
#
#    end station id         end station name  end station latitude  \
# 0            3194          McGinley Square             40.725340
# ...

# %%
Trip_data.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
data = "Resources/CitiBikeRidership-Stations.csv"
stations = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
stations = pd.DataFrame(stations)
stations.tail()
# Out:
#         station id     station name  station latitude  station longitude
# 661709        3694   Jackson Square         40.711130          -74.07890
# 661710        3694   Jackson Square         40.711130          -74.07890
# 661711        3694   Jackson Square         40.711130          -74.07890
# 661712        3694   Jackson Square         40.711130          -74.07890
# 661713        3709  W 15 St & 6 Ave         40.738046          -73.99643

# %%
stations.columns
# Out:
# Index(['station id', 'station name', 'station latitude', 'station longitude'], dtype='object')

# %%
station_list = stations['station name'].unique()
print(station_list)
num_stations = len(station_list)
print(num_stations)
# Out:
# ['Franklin St & W Broadway' 'Barrow St & Hudson St'
#  'MacDougal St & Prince St' 'Hudson St & Reade St' 'Warren St & Church St'
#  'Henry St & Atlantic Ave' 'LaGuardia Pl & W 3 St' 'E 39 St & 3 Ave'
#  'W 16 St & The High Line' 'Old Fulton St' 'Bank St & Washington St'
#  'W 11 St & 6 Ave' 'South St & Whitehall St' 'Maiden Ln & Pearl St'
#  'Duane St & Greenwich St' 'Mercer St & Spring St' 'Broadway & Battery Pl'
#  'Cliff St & Fulton St_1' 'Murray St & West St'
#  'Washington Ave & Park Ave' 'South St & Gouverneur Ln'
#  'Vesey Pl & River Terrace' 'Pike St & Monroe St' 'W 13 St & 6 Ave'
#  'S Portland Ave & Hanson Pl' 'Christopher St & Greenwich St'
#  'E 47 St & Park Ave' 'West Thames St' 'John St & William St'
#  '6 Ave & Canal St' 'Centre St & Worth St' 'Atlantic Ave & Furman St'
#  'Allen St & Rivington St' 'Barclay St & Church St' 'W 59 St & 10 Ave'
#  'W 54 St & 9 Ave' 'West St & Chambers St' 'Bus Slip & State St'
#  'E 7 St & Avenue A' 'Broadway & W 24 St' '8 Ave & W 52 St'
# ...
