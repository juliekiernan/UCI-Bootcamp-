# %%
import os
import csv

import pandas as pd
import numpy as np

# %%
data = "Resources/CitiBikeRidership-MembershipData-2017Q2.csv"
Mem_data2017_Q2 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Mem_data2017_Q2.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  4/1/17                                              23849
# 1  4/2/17                                              39779
# 2  4/3/17                                              43484
# 3  4/4/17                                              29990
# 4  4/5/17                                              47635
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        67299
# 1                                       130087
# 2                                       104217
# 3                                        63091
# 4                                       108281
#
#    Total Annual Members (All Time)  \
# 0                           210739
# 1                           210915
# 2                           211075
# 3                           211171
# 4                           211310
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
data = "Resources/CitiBikeRidership-MembershipData-2017Q3.csv"
Mem_data2017_Q3 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Mem_data2017_Q3.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  7/1/17                                              36737
# 1  7/2/17                                              43035
# 2  7/3/17                                              48193
# 3  7/4/17                                              49924
# 4  7/5/17                                              60321
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       107126
# 1                                       128397
# 2                                       130240
# 3                                       146441
# 4                                       149487
#
#    Total Annual Members (All Time)  \
# 0                           228157
# 1                           228306
# 2                           228473
# 3                           228669
# 4                           228908
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
data = "Resources/CitiBikeRidership-MembershipData-2017Q4.csv"
Mem_data2017_Q4 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Mem_data2017_Q4.head()
# Out:
#       Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  10/1/17                                              55503
# 1  10/2/17                                              65509
# 2  10/3/17                                              69105
# 3  10/4/17                                              71453
# 4  10/5/17                                              70173
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       139011
# 1                                       141748
# 2                                       135800
# 3                                       150324
# 4                                       150437
#
#    Total Annual Members (All Time)  \
# 0                           246193
# 1                           246402
# 2                           246566
# 3                           246742
# 4                           246893
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
data = "Resources/CitiBikeRidership-MembershipData-2018Q1.csv"
Mem_data2018_Q1 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Mem_data2018_Q1.head()
# Out:
#        Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/2018                                               5499
# 1  1/2/2018                                              18818
# 2  1/3/2018                                              24299
# 3  1/4/2018                                               1922
# 4  1/5/2018                                               4972
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        11483
# 1                                        39352
# 2                                        42853
# 3                                         5328
# 4                                        14303
#
#    Total Annual Members (All Time)  \
# 0                           253490
# 1                           253558
# 2                           253591
# 3                           253604
# 4                           253614
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
data = "Resources/CCitiBikeRidership-MembershipData-2018Q2.csv"
Mem_data2018_Q2 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Mem_data2018_Q2.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-93b99fc92fba> in <module>
#       1 data = "Resources/CCitiBikeRidership-MembershipData-2018Q2.csv"
# ----> 2 Mem_data2018_Q2 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
#       3 Mem_data2018_Q2.head()
#
# ...

# %%
data = "Resources/CitiBikeRidership-MembershipData-2018Q3.csv"
Mem_data2018_Q3 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Mem_data2018_Q3.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  7/1/18                                              45265
# 1  7/2/18                                              58633
# 2  7/3/18                                              54882
# 3  7/4/18                                              48368
# 4  7/5/18                                              59471
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                       120484
# 1                                       130122
# 2                                       113998
# 3                                       136287
# 4                                       133659
#
#    Total Annual Members (All Time)  \
# 0                           274813
# 1                           275016
# 2                           275157
# 3                           275304
# 4                           275487
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
data = "Resources/CitiBikeRidership-MembershipData-2019Q2.csv"
Mem_data2019_Q2 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Mem_data2019_Q2.head()
# Out:
#      Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0  1/1/19                                              22145
# 1  1/2/19                                              38249
# 2  1/3/19                                              42181
# 3  1/4/19                                              44420
# 4  1/5/19                                              17636
#
#    Miles traveled today (midnight to 11:59 pm)  \
# 0                                        44131
# 1                                        58975
# 2                                        62500
# 3                                        65739
# 4                                        24326
#
#    Total Annual Members (All Time)  \
# 0                           297823
# 1                           297908
# 2                           297976
# 3                           298017
# 4                           298048
#
#    24-Hour Passes Purchased (midnight to 11:59 pm)  \
# ...

# %%
data = "Resources/JC-201706-citibike-tripdata.csv"
Trip_data2017_06 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2017_06.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           499  2017-06-01 00:01:39  2017-06-01 00:09:59              3195
# 1           507  2017-06-01 00:06:39  2017-06-01 00:15:07              3211
# 2           768  2017-06-01 00:44:43  2017-06-01 00:57:31              3195
# 3           101  2017-06-01 01:12:55  2017-06-01 01:14:36              3185
# 4           265  2017-06-01 01:14:00  2017-06-01 01:18:25              3273
#
#   start station name  start station latitude  start station longitude  \
# 0            Sip Ave               40.730743               -74.063784
# 1         Newark Ave               40.721525               -74.046305
# 2            Sip Ave               40.730743               -74.063784
# 3          City Hall               40.717733               -74.043845
# 4       Manila & 1st               40.721651               -74.042884
#
#    end station id         end station name  end station latitude  \
# ...

# %%
data = "Resources/JC-201707-citibike-tripdata.csv"
Trip_data2017_07 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2017_07.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           340  2017-07-01 00:00:08  2017-07-01 00:05:48              3186
# 1           439  2017-07-01 00:02:35  2017-07-01 00:09:55              3183
# 2           186  2017-07-01 00:04:33  2017-07-01 00:07:40              3186
# 3           442  2017-07-01 00:05:53  2017-07-01 00:13:15              3195
# 4           170  2017-07-01 00:07:54  2017-07-01 00:10:45              3187
#
#   start station name  start station latitude  start station longitude  \
# 0      Grove St PATH               40.719586               -74.043117
# 1     Exchange Place               40.716247               -74.033459
# 2      Grove St PATH               40.719586               -74.043117
# 3            Sip Ave               40.730743               -74.063784
# 4          Warren St               40.721124               -74.038051
#
#    end station id end station name  end station latitude  \
# ...

# %%
data = "Resources/JC-201708 citibike-tripdata.csv"
Trip_data2017_08 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2017_08.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0          1314  2017-08-01 00:03:05  2017-08-01 00:24:59              3187
# 1           221  2017-08-01 00:06:25  2017-08-01 00:10:06              3213
# 2           185  2017-08-01 00:42:28  2017-08-01 00:45:33              3211
# 3            72  2017-08-01 00:45:06  2017-08-01 00:46:18              3269
# 4           499  2017-08-01 01:12:10  2017-08-01 01:20:30              3185
#
#   start station name  start station latitude  start station longitude  \
# 0          Warren St               40.721124               -74.038051
# 1     Van Vorst Park               40.718489               -74.047727
# 2         Newark Ave               40.721525               -74.046305
# 3    Brunswick & 6th               40.726012               -74.050389
# 4          City Hall               40.717733               -74.043845
#
#    end station id end station name  end station latitude  \
# ...

# %%
data = "Resources/JC-201712-citibike-tripdata.csv"
Trip_data2017_12 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2017_12.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           452  2017-12-01 00:00:59  2017-12-01 00:08:32              3183
# 1           159  2017-12-01 00:04:42  2017-12-01 00:07:21              3187
# 2           175  2017-12-01 00:17:00  2017-12-01 00:19:55              3186
# 3           455  2017-12-01 00:50:22  2017-12-01 00:57:57              3194
# 4           670  2017-12-01 00:55:03  2017-12-01 01:06:13              3194
#
#   start station name  start station latitude  start station longitude  \
# 0     Exchange Place               40.716247               -74.033459
# 1          Warren St               40.721124               -74.038051
# 2      Grove St PATH               40.719586               -74.043117
# 3    McGinley Square               40.725340               -74.067622
# 4    McGinley Square               40.725340               -74.067622
#
#    end station id      end station name  end station latitude  \
# ...

# %%
data = "Resources/JC-201801-citibike-tripdata.csv"
Trip_data2018_01 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2018_01.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           932  2018-01-01 02:06:17.5410  2018-01-01 02:21:50.0270
# 1           550  2018-01-01 12:06:18.0390  2018-01-01 12:15:28.4430
# 2           510  2018-01-01 12:06:56.9780  2018-01-01 12:15:27.8100
# 3           354  2018-01-01 14:53:10.1860  2018-01-01 14:59:05.0960
# 4           250  2018-01-01 17:34:30.1920  2018-01-01 17:38:40.9840
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3199     Newport Pkwy
# ...

# %%
data = "Resources/JC-201802-citibike-tripdata.csv"
Trip_data2018_02 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2018_02.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           134  2018-02-01 07:38:15.8650  2018-02-01 07:40:30.5820
# 1           413  2018-02-01 08:19:35.8160  2018-02-01 08:26:29.6490
# 2            77  2018-02-01 08:31:03.0860  2018-02-01 08:32:20.3510
# 3           404  2018-02-01 15:23:15.0850  2018-02-01 15:29:59.9300
# 4           230  2018-02-01 15:26:01.8240  2018-02-01 15:29:52.5440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
data = "Resources/JC-201806-citibike-tripdata.csv"
Trip_data2018_06 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2018_06.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           329  2018-06-01 07:07:00.2990  2018-06-01 07:12:30.2220
# 1           259  2018-06-01 08:24:43.8490  2018-06-01 08:29:03.8450
# 2           686  2018-06-01 09:17:49.5730  2018-06-01 09:29:16.1770
# 3           164  2018-06-01 09:44:00.4020  2018-06-01 09:46:44.6830
# 4           769  2018-06-01 09:59:28.7800  2018-06-01 10:12:18.6660
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id  end station name  \
# 0               -74.033459            3276  Marin Light Rail
# ...

# %%
data = "Resources/JC-201807-citibike-tripdata.csv"
Trip_data2018_07 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2018_07.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
data = "Resources/JC-201808-citibike-tripdata.csv"
Trip_data2018_08 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2018_08.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           903  2018-08-01 06:40:33.3610  2018-08-01 06:55:37.1060
# 1            78  2018-08-01 08:21:00.1450  2018-08-01 08:22:18.6310
# 2           405  2018-08-01 08:43:52.5150  2018-08-01 08:50:37.6140
# 3           155  2018-08-01 09:48:24.9450  2018-08-01 09:51:00.9360
# 4           453  2018-08-01 12:15:35.1230  2018-08-01 12:23:08.8880
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3270  Jersey & 6th St
# ...

# %%
data = "Resources/JC-201812-citibike-tripdata.csv"
Trip_data2018_12 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2018_02.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           134  2018-02-01 07:38:15.8650  2018-02-01 07:40:30.5820
# 1           413  2018-02-01 08:19:35.8160  2018-02-01 08:26:29.6490
# 2            77  2018-02-01 08:31:03.0860  2018-02-01 08:32:20.3510
# 3           404  2018-02-01 15:23:15.0850  2018-02-01 15:29:59.9300
# 4           230  2018-02-01 15:26:01.8240  2018-02-01 15:29:52.5440
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3184      Paulus Hook
# ...

# %%
data = "Resources/JC-201901-citibike-tripdata.csv"
Trip_data2019_01 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2019_01.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           201  2019-01-01 03:09:09.7110  2019-01-01 03:12:30.8790
# 1           505  2019-01-01 05:18:00.1060  2019-01-01 05:26:25.9050
# 2           756  2019-01-01 10:36:33.3400  2019-01-01 10:49:10.2600
# 3          1575  2019-01-01 12:43:38.6430  2019-01-01 13:09:54.5280
# 4          1566  2019-01-01 12:43:39.6010  2019-01-01 13:09:46.5100
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id    end station name  \
# 0               -74.033459            3214    Essex Light Rail
# ...

# %%
data = "Resources/JC-201902-citibike-tripdata.csv"
Trip_data2019_02 = pd.read_csv(data, low_memory=False, encoding="ISO-8859-1")
Trip_data2019_02.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1           223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2           106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3           370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4           315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3639       Harborside
# ...
